# %% [markdown]
# # Pycaret - Binary Classification

# %% [markdown]
# For more info:
# https://github.com/pycaret/pycaret/blob/master/tutorials/Binary%20Classification%20Tutorial%20Level%20Beginner%20-%20%20CLF101.ipynb

# %% [markdown]
# Binary classification on people who use default payment.

# %% [markdown]
# ## Data Loading

# %%
# Load data from pycaret
from pycaret.datasets import get_data

dataset = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
#check the shape of data
dataset.shape
# Out:
# (24000, 24)

# %%
# Data for training and validation
data = dataset.sample(frac=0.95, random_state=786)

# Data to be predicted
data_unseen = dataset.drop(data.index)

data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (22800, 24)
# Unseen Data For Predictions: (1200, 24)

# %% [markdown]
# ## Setup Pycaret Environment

# %%
# Setup pycaret environment
from pycaret.classification import *

exp_clf101 = setup(data = data, target = 'default', session_id=123)
# Out:
# <style  type="text/css" >
# </style><table id="T_c56df_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c56df_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c56df_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c56df_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_c56df_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c56df_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_c56df_row1_col1" class="data row1 col1" >default</td>
#             </tr>
#             <tr>
#                         <th id="T_c56df_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# ## Model Evaluation

# %%
# Model evaluation
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_79c2e_ th {
#           text-align: left;
# ...

# %% [markdown]
# ## Create a model

# %% [markdown]
# Choice of model and how to access it

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# ...

# %% [markdown]
# ### Decision Tree

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
# #T_07186_row10_col0,#T_07186_row10_col1,#T_07186_row10_col2,#T_07186_row10_col3,#T_07186_row10_col4,#T_07186_row10_col5,#T_07186_row10_col6{
#             background:  yellow;
#         }</style><table id="T_07186_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_07186_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_07186_row0_col0" class="data row0 col0" >0.7331</td>
# ...

# %%
#trained model object is stored in the variable 'dt'. 
print(dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %% [markdown]
# ### K-nearest-neighbor

# %%
knn = create_model('knn')
# Out:
# <style  type="text/css" >
# #T_46c2e_row10_col0,#T_46c2e_row10_col1,#T_46c2e_row10_col2,#T_46c2e_row10_col3,#T_46c2e_row10_col4,#T_46c2e_row10_col5,#T_46c2e_row10_col6{
#             background:  yellow;
#         }</style><table id="T_46c2e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_46c2e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_46c2e_row0_col0" class="data row0 col0" >0.7469</td>
# ...

# %%
#trained model object is stored in the variable 'dt'. 
print(knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# ### Random Forest

# %%
rf = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_72f68_row10_col0,#T_72f68_row10_col1,#T_72f68_row10_col2,#T_72f68_row10_col3,#T_72f68_row10_col4,#T_72f68_row10_col5,#T_72f68_row10_col6{
#             background:  yellow;
#         }</style><table id="T_72f68_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_72f68_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_72f68_row0_col0" class="data row0 col0" >0.8114</td>
# ...

# %%
print(rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ## Tune Model

# %%
# Auto-tune model using random grid
tuned_dt = tune_model(dt)
print(tuned_dt)

tuned_rf = tune_model(rf)
print(tuned_rf)
# Out:
# <style  type="text/css" >
# #T_2e5e3_row10_col0,#T_2e5e3_row10_col1,#T_2e5e3_row10_col2,#T_2e5e3_row10_col3,#T_2e5e3_row10_col4,#T_2e5e3_row10_col5,#T_2e5e3_row10_col6{
#             background:  yellow;
#         }</style><table id="T_2e5e3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e5e3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2e5e3_row0_col0" class="data row0 col0" >0.8158</td>
# ...

# %%
# Auto tune with custom grid
import numpy as np
tuned_knn = tune_model(knn, custom_grid = {'n_neighbors' : np.arange(0,50,1)})
print(tuned_knn)
# Out:
# <style  type="text/css" >
# #T_f5b8c_row10_col0,#T_f5b8c_row10_col1,#T_f5b8c_row10_col2,#T_f5b8c_row10_col3,#T_f5b8c_row10_col4,#T_f5b8c_row10_col5,#T_f5b8c_row10_col6{
#             background:  yellow;
#         }</style><table id="T_f5b8c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5b8c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f5b8c_row0_col0" class="data row0 col0" >0.7813</td>
# ...

# %%
plot_model(tuned_rf, plot = 'auc')

# %%
plot_model(tuned_rf, plot = 'pr')

# %%
plot_model(tuned_rf, plot='feature')

# %%
plot_model(tuned_rf, plot='feature')

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## Pedict model on test data that has automatically seperated from train data set

# %%
predict_model(tuned_rf)
# Out:
# <style  type="text/css" >
# </style><table id="T_acadd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_acadd_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_acadd_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#                         <td id="T_acadd_row0_col1" class="data row0 col1" >0.8116</td>
#                         <td id="T_acadd_row0_col2" class="data row0 col2" >0.7407</td>
# ...

# %% [markdown]
# ### Finalize the model

# %%
# Fits the model to the remaining test data set
final_rf = finalize_model(tuned_rf)

# Final Random Forest model parameters for deployment
print(final_rf)

# Re-predict the data
predict_model(final_rf)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight={},
#                        criterion='entropy', max_depth=5, max_features=1.0,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0002, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=150,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)
# <style  type="text/css" >
# ...

# %% [markdown]
# ## Predict unseen data

# %%
unseen_predictions = predict_model(final_rf, data=data_unseen)
unseen_predictions.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0     100000    2          2         2   23      0     -1     -1      0
# 1     380000    1          2         2   32     -1     -1     -1     -1
# 2     200000    2          2         1   32     -1     -1     -1     -1
# 3     200000    1          1         1   53      2      2      2      2
# 4     240000    1          1         2   41      1     -1     -1      0
#
#    PAY_5  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0      0  ...      567.0     380.0     601.0       0.0     581.0    1687.0
# 1     -1  ...    11873.0   21540.0   15138.0   24677.0   11851.0   11875.0
# 2      2  ...     3151.0    5818.0      15.0    9102.0      17.0    3165.0
# 3      2  ...   149531.0    6300.0    5500.0    5500.0    5500.0    5000.0
# 4      0  ...     1737.0    2622.0    3301.0       0.0     360.0    1737.0
#
#    PAY_AMT6  default  Label   Score
# 0    1542.0        0      0  0.8051
# ...

# %%
from pycaret.utils import check_metric
check_metric(unseen_predictions['default'], unseen_predictions['Label'], metric = 'Accuracy')
# Out:
# 0.8167

# %% [markdown]
# ## Saving and Loading model

# %%
# Save Model
save_model(final_rf,'rf_model')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='default',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                   RandomForestClassifier(bootstrap=False, ccp_alpha=0.0,
#                                          class_weight={}, criterion='entropy',
# ...

# %%
# Load Model
saved_final_rf = load_model('rf_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(saved_final_rf, data=data_unseen)
new_prediction.head()

from pycaret.utils import check_metric
check_metric(new_prediction['default'], new_prediction['Label'], metric = 'Accuracy')
# Out:
# 0.8167
