# %% [markdown]
# # Chapter 2: Fully Connected Networks
#
# The goal in this chapter is to:
#
#
# * Implement a training loop in Pytorch
# * Changing loss function for regression and classification problems
# * Implementing and training a fully connected network
# * Training faster using smaller batches of data

# %% [markdown]
# ## Implementing training loop

# %% [markdown]
# We will first learn how to set up this optimization approach to learn. This process often known as __training loop__.
#
# We will start with two basic algorithms (linear and logistic regression) to learn how training loop work for classification and regression.
#
# The vector of weights that makes a logistic/linear regression is also called a linear layer or a fully connected layer.
#
# This means both can be described as a “single layer” model in PyTorch. The model can be seen below.
#
# <img src="https://drive.google.com/uc?export=view&id=1tZoGHyTslqFbx1oISuFzesOYFo_Yri40" alt="drawing" width="200"/>

# %% [markdown]
# ## Neural network as optimization

# %% [markdown]
# In the last chapter, we defined a loss function to minimize and used the .backward() function to compute gradients, which told us how to alter the parameters to minimize the function.
#
# If we make the input to the loss function a neural network, then we can use this exact same approach to train a neural network.
#
# This creates a process called a training loop with three major components:
# 1. the training data (with correct answers),
# 2. the model and loss function, and
# 3. the update via gradients.
#
# These three components are outlined in Figure below.
#
# <img src="https://drive.google.com/uc?export=view&id=1gyZQocsObBYFzylRBVroLzW2nrYLeRq4" alt="drawing" width="600"/>

# %% [markdown]
# Assume that $x$ is our input feature and $f()$ is our network model. The label associated with $x$ is $y$.
#
# Our model takes in $x$ producing $\hat{y}$, which can be written as:
#
# $$\hat{y}=f(x)$$
#
#
# Then, our model also need a parameter to alter it's prediction and reduce the loss function. This parameter will be denoted as $\Theta$
#
# We can also explicitly say that a function is dependent to a parameter as shown below:
#
# $$\hat{y}=f_{\Theta}(x)$$
#
# Next, we also need to define a loss function to quantifies how badly our model at predicting the ground truth. If $y$ is the desired label and $\hat{y}$ is our prediction, the loss function can be denoted as $$l(y,\hat{y})$$
#
# Now let's say that we have a training set with $N$ samples. Our loss function can be stated as  $$\min_{\Theta} \sum_{i=1}^{N} l(f_{\Theta}(x_{i}), y_{i})$$
#
# Which can be read as below:
#
# <img src="https://drive.google.com/uc?export=view&id=1Lcf-mOJ-3EsF9UZa-gOAbHZBF98gQsZe" alt="drawing" width="600"/>
#
# If we implement it, the code would look like below:

# %%
def F(X, y, f, theta):
    N = len(X)
    total_loss =0
    for i in range(N):
        total_loss += loss(f(X[i,:], theta), y[i])
    return total_loss

# %% [markdown]
# After calculating the loss, the next question is how to adjust the $\Theta$?
#
# Let's say that $\Theta_{k}$ is the current state of our model. We want to define  $\Theta_{k+1}$, that hopefully reduces our model's loss. To solve this we can use the mathematical model below.
#
# $$\Theta_{k+1}= \Theta_{k}-\eta \cdot \frac{1}{N} \sum_{i=1}^N \nabla_{\Theta_{k}}l(f_{\Theta}(x_{i}), y_{i})$$
#
# The equation above is known as "gradient decent".
# The nabla $\nabla$ in the equation is the gradient we use to refer to the
# derivative with respect to every parameter.
#
# If we want to alter a subset $z$ of the parameters, we would write it as $\nabla_z$.
#
# This means $\nabla$ is going to be a tensor, with one value for every parameter.

# %% [markdown]
# ## Linear Regression

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import BatchSampler
from idlmam import *
import matplotlib.pyplot as plt

# %% [markdown]
# ### The training loop

# %% [markdown]
# Suppose that we have loss function ($l(\cdot, \cdot)$) that takes a prediction ($\hat{y}$) and a target ($y$), returning a single score which defines how well a model ($f(\cdot)$) has done.
#
# We will need an iterator that loads the training data for us to train on. This **training_loader** will gives us pairs of inputs with their associated labels for training.
#
# <img src="https://drive.google.com/uc?export=view&id=1Ij-Ln_SXIK2e4y_klMzbvG8mvCQV_Mqe" alt="drawing" width="600"/>
#
# * Yellow : The "prep" section shows the object creation that needs to be done before the training can start.
# * Red : Indicate the start/repetition of the "loop", which provides new data for us to train on.
# * Blue : Computes the prediction and loss for the model with its current $\Theta$
# * Green : Taking loss, computing the gradients, and updates $\Theta$
#
# This concept is applied on the code below

# %%
from tqdm.autonotebook import tqdm

import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd

import time

# %%
def train_simple_network(model, loss_func, training_loader, epochs=20, device="cpu"):
    # Yellow steps
    # Defining optimizer, which is SGD over the parameter \theta
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    # Place the model to the correct compute resource (CPU or GPU)
    model.to(device)

    # Red steps
    # Loop through all the data (batches) multiple times(epochs)
    for epoch in tqdm(range(epochs), desc="Epoch"):
        # Put model in training mode
        model = model.train()
        running_loss = 0.0

        for inputs, labels in tqdm(training_loader, desc="Batch", leave=False):
            # Move the batch of data to the device we are using.
            inputs = moveTo(inputs, device)
            labels = moveTo(labels, device)

            # PyTorch store gradients in mutable data structure
            # Hence, we need to clean it manually
            optimizer.zero_grad()

            # Blue steps
            # Compute prediction
            y_hat = model(inputs)

            # Compute loss
            loss = loss_func(y_hat, labels)

            # Green steps
            # Compute gradient
            loss.backward()

            # Update Parameters
            optimizer.step()

            running_loss += loss.item()

# %% [markdown]
# Now, we have a code to train the network. Now, let's try to learn simple Linear Regression problem and apply it to a real world scenario that can be solve by a linear regression (e.g., predicting miles per gallon of a car based on it's features, such as weight in pounds, engine size, year produced).
#
# First, let's create a synthetic regression problem which has a linear and non-linear component.

# %%
# Create a 1-dimensional input
X = np.linspace(0,20, num=200)
# Create an output
y = X + np.sin(X)*2 + np.random.normal(size=X.shape)
sns.scatterplot(x=X, y=y)
plt.show()

# %% [markdown]
# Below we create a simple dataset object that knows we have a 1-dimensional problem. The training data will be shaped as $(n, 1)$ matrix, where $n$ is the
# number of data points we have. The labels $(y)$ will take a similar form.

# %%
class Simple1DRegressionDataset(Dataset):

    def __init__(self, X, y):
        super(Simple1DRegressionDataset, self).__init__()
        data = X.reshape(-1,1)
        print(data.shape)
        print(X.shape)
        self.X = X.reshape(-1,1)
        self.y = y.reshape(-1,1)

    def __getitem__(self, index):
        return torch.tensor(self.X[index,:], dtype=torch.float32), torch.tensor(self.y[index], dtype=torch.float32)

    def __len__(self):
        return self.X.shape[0]

training_loader = DataLoader(Simple1DRegressionDataset(X, y), shuffle=True)
# Out:
# (200, 1)
# (200,)

# %% [markdown]
# ### Defining the model, loss function, and learning

# %% [markdown]
# At this point, we have successfully created a training loop, and a dataset. Our next aim is to define the model $f_\Theta(x)$, which is a Linear Regression Algorithm as a network.

# %% [markdown]
# In defining our network, we want a simple linear function. This linear function means a weight matrix $W$. Applying $W$ to an input **x** means taking the matrix vector product. This $f(\cdot)$ will look like this: $$f(x)=x^T W^{d, C}$$, where **x** has $d$ features (in this case, d=1) and the $W$ matrix will have a row for every feature, and a column for every output $W^{d, C}$, which can be explicitly state as $d=row$ and $C=column$.

# %% [markdown]
# However, this linear function is not yet complete. If $x = 0$, then $f(x) = 0$. Hence, we need to add a bias term $b$ which has no interaction to $x$. $$f(x) = x^T W^{d, C} + b$$ By adding this bias term, we allow the "model" to shift to left or right as needed.

# %% [markdown]
# ### Defining the loss function

# %% [markdown]
# Using $f(x)$ we can get the prediction $\hat{y}=f(x)$ and we know we have our ground truth $y$.
#
# Now, we have these value, how do we calculate the difference? We can do this by calculating the absolute difference $l(y,\hat{y})=|y - \hat{y}|$ (the L1Loss).
#
# Why do we need absolute? Because, supose we have a test case where $\hat{y} < y$, this will give us a positive loss, encouraging to make it's prediction small. However, if the case is $\hat{y} > y$, this will give us negative loss and this is confusing since it is encouraging us to shift to a smaller value while the difference is already to high. So, we tend to keep the loss from positive number to 0, but not less.

# %% [markdown]
# Another loss that we have is the Mean Squared Error (MSE) loss $l(y, \hat{y})=(y - \hat{y})^2$. This will result in the growth of result when both value move farther away.

# %%
in_features =1
out_features =1
model = nn.Linear(in_features, out_features)
loss_func = nn.MSELoss()
device = torch.device("cuda")
train_simple_network(model, loss_func, training_loader, device=device)
# Out:
# ...
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]

# %% [markdown]
# Now that we have train the model, we want to test it out. We will use the with torch.no_grad(): context to get those predictions.
#
# This context tells PyTorch that for any computation done within the scope of the no_grad() block, do not calculate gradients.
# This is because we only want gradients to be computed during training. Several aspects that is taken into account:
#
#
#     1. The gradient calculations take additional time, memory, and can cause bugs if we want to train the model more after performing a prediction.

# %%
with torch.no_grad():
    Y_pred = model(torch.tensor(X.reshape(-1,1), device=device,
    dtype=torch.float32)).cpu().numpy()

# %%
#The data
sns.scatterplot(x=X, y=y, color='blue', label='Data') 

#What our model learned
sns.lineplot(x=X, y=Y_pred.ravel(), color='red', label='Linear Model') 
plt.show()

# %% [markdown]
# ## Building Our First Network

# %% [markdown]
# The previous example is the foundational framework we will use for all "learning" in deep learning. In order to train a neural network, we only need to replace the model object that we have defined. If the we define a good model, from our previous example, it should capture the smaller oscillations and the larger linear trend.

# %% [markdown]
# When talking about neural network and deep learning, we will come accross the term "layers". Layers are the building blocks we use to define our model.

# %% [markdown]
# The model that we are going to build is a simple **feed-forward fully-connected neural network**.
#
# It is called **feed-forward** because **every output** from one layer will **flow directly to the next layer**. So, each layer will have **one input and one output** and progress in **equential** manner.
#
# It is called **fully-connected** because each following node within the network will have connections from all the nodes from the previous layer.

# %% [markdown]
# ### The model
#
# Let's assume that we have a "hidden layer", "input layer" ($x$), and an "output layer" ($R^{C}$).
#
# You can think the hidden layer as anything a sandwich has in between.
#
# So, instead of using the calculation before:
# $$f(x)=x^T W^{d, C}$$
#
# We will have:
# $$f(x)=x^T W_{h_1}^{d \times n}  W^{n, C}$$
#
# Notice that we have a new variable $n$ (hidden layer size). It is called a hyper-parameter for us to tune and deal with.
#
# The picture below shows a simple model of a FCNN.
# <img src="https://drive.google.com/uc?export=view&id=1pEtdX6gdRWR1nYQt98PppFfyWg4S7RRS" alt="drawing" width="200"/>
#
# The black line connecting input to hidden nodes corresponse to an <code>nn.Linear(3, 4)</code> layer, which is a matrix of $W^{3 \times 4}$. Every column of that matrix corresponds to the inputs of one of the n=4 "neurons" or outputs of that layer. In the same fashion, the lines from hidden to output of the Figure would be <code>nn.Linear(4, 1)</code>
#
# Below is the example of code using <code>nn.Sequential()</code>, which is the simplest way to specify neural networks in PyTorch.

# %%
#Input "layer" is implicitly the input
model = nn.Sequential(
    nn.Linear(1, 10), #Hidden layer
    nn.Linear(10,1), #Output layer
)

train_simple_network(model, loss_func, training_loader)
# Out:
# ...
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
with torch.no_grad():
    Y_pred = model(torch.tensor(X.reshape(-1,1), dtype=torch.float32)).cpu().numpy()
    sns.scatterplot(x=X, y=y, color='blue', label='Data') #The data
    sns.lineplot(x=X, y=Y_pred.ravel(), color='red', label='Model') #What our model learned
    plt.show()

# %% [markdown]
# After adding the hidden layer with the size of 10, with 1 input and output layer, why does the model still perform poorly?
#
# Looking closely to the function, first, we have:
# $$f(x)=x^T W_{h_1}^{d, n} W_{out}^{n, C}$$
#
# Simplifying using algebra we can note that
# $$W_{h_1}^{d, n} W_{out}^{n, C} = \tilde{W}_{d, c}$$
#
# This is equivalent to the linear model that we write. Placing multiple linear layers one after another is a redundant application and a common error.

# %% [markdown]
# ### Adding non-linearity

# %% [markdown]
# In order to fix this problem, we need a non-linearity between every step. This can be done by inserting a non-linear function after every linear operation. These functions are called **activation function**.
#
# Now, the question is what activation function should we use?
# let's first look at two common functions: $sigmoid (\sigma (\cdot ))$ and the $hyperbolic  tangent (tanh (\cdot ))$.
#
# The tanh, maps everything into the range:
# $$tahh(x)=\frac{sinh\:x}{cosh\:x}=\frac{e^x-e^{-x}}{e^x+e^{-x}}$$
#
# The Sigmoid, maps everything into the range of [0, 1].
# $$\sigma(x)=\frac{e^x}{e^x+1}$$

# %%
activation_input = np.linspace(-2,2, num=200)
tanh_activation = np.tanh(activation_input)
sigmoid_activation = np.exp(activation_input)/(np.exp(activation_input)+1)
sns.lineplot(x=activation_input, y=activation_input, color='black', label="linear")
sns.lineplot(x=activation_input, y=tanh_activation, color='red', label="tanh(x)")
ax = sns.lineplot(x=activation_input, y=sigmoid_activation, color='blue', label="$\sigma(x)$")
ax.set_xlabel('Input value x')
ax.set_ylabel('Activation')
plt.show()

# %% [markdown]
# As promised, the sigmoid activation $(\sigma(x))$ maps everything to a minimum of 0, and a maximum of 1. The tanh function goes from -1 to 1. From the ploted graph above, either function is fine.
#
# The final model will look like below:
# $$f(x)=tanh(x^T W_{h_1}^{d, n}) W_{out}^{n, C}$$

# %%
model = nn.Sequential(
        nn.Linear(1, 20),#hidden layer
        nn.Tanh(),#activation
        nn.Linear(20,1),#output layer
    )

train_simple_network(model, loss_func, training_loader, epochs=200)
# Out:
# ...
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
with torch.no_grad():
    Y_pred = model(torch.tensor(X.reshape(-1,1), dtype=torch.float32)).cpu().numpy()

# The data
sns.scatterplot(x=X, y=y, color='blue', label='Data') 

# What our model learned
sns.lineplot(x=X, y=Y_pred.ravel(), color='red', label='Model') 

plt.show()

# %% [markdown]
# ## Classification Problem

# %% [markdown]
# ### Classification Toy Problem

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=200, noise=0.05)
sns.scatterplot(x=X[:,0], y=X[:,1], hue=y, style=y)

plt.show()

# %% [markdown]
# Looking at the problem , moons dataset has $d=2$ input features, it also has two different classes. Since we know that the classification will be either 1 or 0 not floating points, we need to present our label as integers.

# %%
classification_dataset = torch.utils.data.TensorDataset(torch.tensor(X, dtype=torch.float32),
torch.tensor(y, dtype=torch.long))
training_loader = DataLoader(classification_dataset)

# %%
in_features =2
out_features =2
model = nn.Linear(in_features, out_features)

# %% [markdown]
# ### Loss Function

# %% [markdown]
# Since this problem is different from the linear regression problem, we need to determine a different loss function in order to calculate the loss of the prediction $\hat{y}$.
#
# There is one technique which requires two components: the softmax function and the cross-entropy. These functions, when combined, is usually called the cross-entropy loss.

# %% [markdown]
# #### Softmax

# %% [markdown]
# Since now we have two nodes in the output layer, first, we intuitively want the dimension in $\hat{y}$ that has the largest value to correspond to the correct class label y (np.argmax).
# $$y=\underbrace{argmax_i\:\hat{y_i}}_{np.argmax(\hat{y})}$$
#
# Other thing is that our prediction sould be a sensible probability. Suppose that correct class is $y=k$, and that $\hat{y_k}$ is the largest value that we have. What if $\hat{y_k}-\hat{y_j} = 0.00001$?
#
# The difference is too small.
#
# if we made $\hat{y}$ into probabilities, then the sum of all probabilities is up to 1. This means:
#
# $$\underbrace{\sum_{i=0}^{C-1} \hat{y_i}}_{np.sum(\hat{y})} = 1$$
#
# This way we know that the model is confident in its prediction if $\hat{y_k}=1 \;\; \forall \; k \neq j$. If the model was less confident, we might see $\hat{y_k} = 0.9$.

# %% [markdown]
# The softmax function is what we will use in this matter. Bellow is the equation of the softmax.
#
# $$softmax(x)_i = \frac{exp(x_i)}{\sum_{j=1}^{d}exp(x_j)}$$
#
# In further detail,
#
# $softmax(x)_i$ is the probability of the i'th item
#
# $exp(x_i)$ is the score of the i'th item
#
# $\sum_{j=1}^{d}exp(x_j)$ is the sum of all item's score

# %% [markdown]
# #### Cross-entropy

# %% [markdown]
# After defining the softmax probability score, we need to define a loss function. One loss function commonly used corresponding to this probability score function is called the softmax function.
#
# If we had two probability distribution $p$ and $q$, the cross entropy between these two can be denoted as:
#
# $$l(p, q)=-\sum_{i=1}^d p_i \cdot log(q_i)$$

# %% [markdown]
# Why do we use cross entropy? Suppose that we have a predicted distribution $q$ while the actual distribution is $p$. This function will help us boils down to telling us how different is the two distributions are.
#
# <img src="https://drive.google.com/uc?export=view&id=1JuN-fe0_twGRTQPK3uqeu6JRgnZIRndA" alt="drawing" width="600"/>

# %% [markdown]
# Now, when the two tools are combined, we first will apply the softmax function then the cross-entropy, which can be denoted as:
#
# $$l(\hat{y}, y) = -log(sm(\hat{y})_y)$$
#
# , which in further explanation states that:
#
# $l(\hat{y}, y)$, is the loss between the prediction $\hat{y}$ and the actual class $y$.
#
# $-log()$, is the negative log (makes it so that "good" values are smaller and "bad" are larger)
#
# $sm(\hat{y})_y$, is the predicted probability of the correct class.
#
# In code, we can write it using a single function provided by PyTorch, which already combine this both functions.

# %%
loss_func = nn.CrossEntropyLoss()
train_simple_network(model, loss_func, training_loader, epochs=50)
# Out:
# ...
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]

# %% [markdown]
# Now, let's visualize the results. Since this problem is a 2-d function, unlike the previous regression problem, we need a more complex visualization procedure.
#
# Let's create a contour-plot where the dark blue represents the first class and dark red represents the second class, with the lightness of the colour as the confidence level of the model. (light = not confident, dark = confident).

# %%
def visualize2DSoftmax(X, y, model, title=None):
    
    x_min = np.min(X[:,0])-0.5
    x_max = np.max(X[:,0])+0.5
    y_min = np.min(X[:,1])-0.5
    y_max = np.max(X[:,1])+0.5
    
    xv, yv = np.meshgrid(np.linspace(x_min, x_max, num=20), np.linspace(y_min, y_max, num=20),
            indexing='ij')
    
    xy_v = np.hstack((xv.reshape(-1,1), yv.reshape(-1,1)))
    
    with torch.no_grad():
        logits = model(torch.tensor(xy_v, dtype=torch.float32))
        y_hat = F.softmax(logits, dim=1).numpy()
        
    cs = plt.contourf(xv, yv, y_hat[:,0].reshape(20,20), levels=np.linspace(0,1,num=20),
        cmap=plt.cm.RdYlBu)
    sns.scatterplot(x=X[:,0], y=X[:,1], hue=y, style=y, ax=cs.ax)
    
    if title is not None:
        cs.ax.set_title(title)
    
    plt.show()
        
visualize2DSoftmax(X, y, model)
# Out:
# <ipython-input-19-319312e34d6c>:19: MatplotlibDeprecationWarning:
# The ax attribute was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   sns.scatterplot(x=X[:,0], y=X[:,1], hue=y, style=y, ax=cs.ax)

# %% [markdown]
# Above we can now see the results of our model on this data. Overall a decent job, most of the blue circles are in the blue region, and the red crosses in the red region. There is a middle ground where errors are being made, because our problem can not be fully solved with a linear model.
#
# Now we do the same as the regression model by adding the non-linearity.

# %%
model = nn.Sequential(
        nn.Linear(2, 30),
        nn.Tanh(),
        nn.Linear(30, 30),
        nn.Tanh(),
        nn.Linear(30,2),
        )

train_simple_network(model, loss_func, training_loader, epochs=250)
# Out:
# ...
# Batch:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
visualize2DSoftmax(X, y, model)
# Out:
# <ipython-input-19-319312e34d6c>:19: MatplotlibDeprecationWarning:
# The ax attribute was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   sns.scatterplot(x=X[:,0], y=X[:,1], hue=y, style=y, ax=cs.ax)

# %% [markdown]
# ## Better Training Code

# %% [markdown]
# From the previous example, we have successfully trained our FCNN for regression and classification problem. However, we have been training and evaluating our model using the same data, which is not okay. Also, when dealing with classification problem, our goal is not to minimize the cross-entropy loss but to minimize the error. Yet, we can't define "errors" in a differentiable way that will work with pytorch.
#
# In this case, some changes are needed to make the training code more robust. First, a training set and a testing set will be created. Then, other metrics to evaluate the model is also added to score the performance as the model is trained.

# %% [markdown]
# ### Custom Metrics

# %% [markdown]
# As mentioned before, the metrics that we care about (e.g., accuracy) may not be the same as the loss we used to train our model (e.g., cross-entropy). There are many ways that both could not match together perfectly.
#
# Onre reason is because a loss function must have the property of being *differentiable* (if a function has a derivative), and most of the time our true goal does not have this property.
#
# To tackle this problem, the code needs to be changed such that we can bass in functions to compute different metrics from the labels and predicted values.
#
# To make our life easy, we will make it so our code will work well with most of the metrics provided by the Scikit-Learn library (https://scikit-learn.org/stable/modules/model_evaluation.html#common-cases-predefined-values).

# %% [markdown]
# First, we need a way for the user to speciry which function they want to evaluate. For the score functions, let's use a dictionary <code>score_funcs</code>.
# ```python
# score_funcs={
#     'Acc': accuracy_score,
#     'F1': f1_score
# }
# ```
# This way we can specify as many metrics as we want, as long as we implement a function <code>score_funcs(y_true, y_predict)</code>.
#
# After each epoch of the loop, we can use another dictionary results that maps strings as keys to a list of results. Well use a list so that we have one score for each epoch.
# ```python
# results[prefix+" loss"].append(np.mean(running_loss))
# for name, score_func in score_funcs.items():
#     results[prefix+" "+name].append(score_func(y_true, y_pred))
# ```
#
# If we justed used the name of each score function, we would not be able to differentiate between the score on the training set and the testing set.
#
# This is important, because if there is a wide gap that could be an indicator of over-fitting, and a small gap could indicate under-fitting.
#
# So we will use a prefix to distinguish between "train" and "test" scores.

# %% [markdown]
# ### Training and Testing Passes

# %% [markdown]
# Performing training or evaluation requires different inputs:
#
# 1. model: the PyTorch Module to run for one epoch that represents our model $f(\cdot)$.
# 2. optimizer: the object that will update the weights of the network __should only be used if training is performed__
# 3. data_loader: DataLoader object that returns tuples of (input, label) pairs.
# 4. loss_function: The loss function $l(\cdot, \cdot)$ that takes the prediction and the true label. It returns a loss to be used for training.
# 5. device: The compute device used (CPU/GPU)
# 6. results: A dictionary of strings to lists the results described above.
# 7. score_funcs: A dictionary of scoring functions to use to evaluate the performance of the model.
# 8. prefix: A string prefix to any scores placed into the results dictionary.
# 9. desc: A descriptive string for a progress bar
#
# ```python
# def run_epoch(model, optimizer, data_loader, loss_func, device,
# results, score_funcs, prefix="", desc=None):
# ```

# %% [markdown]
# Variable initialization
# ```python
# running_loss = []
# y_true = []
# y_pred = []
# start = time.time()
# ```

# %% [markdown]
# Check if we need to use optimizer or not (if the model is training or not)
# model = model.train() will return model.training = True,
# while model = model.eval() will return model.training = False
#
# Hence, we can wrap the bakcward(), step(), and zero_grad() under this flag
#
# ```python
# if model.training:
#     loss.backward()
#     optimizer.step()
#     optimizer.zero_grad()
# ```

# %% [markdown]
# We also need to store the labels and predictions into y_true and y_pred respectively.
#
# ```python
# if len(score_funcs) >0:
#     #moving labels & predictions back to CPU for later
#     labels = labels.detach().cpu().numpy()
#     y_hat = y_hat.detach().cpu().numpy()
#     #add to predictions so far
#     y_true.extend(labels.tolist())
#     y_pred.extend(y_hat.tolist())
# ```

# %% [markdown]
# Lastly we will make the model to have the ability to save a simple checkpoint of the most recently completed epoch.
# ```python
# torch.save({
#     'epoch': epoch,
#     'model_state_dict': model.state_dict(),
#     'optimizer_state_dict': optimizer.state_dict(),
#     'results' : results
#     }, checkpoint_file)
# ```
# The second argument checkpoint_file is simply a path to where we should save the file. We can put any picklable object into this dictionary to be saved.

# %% [markdown]
# #### Putting it all together

# %%
def run_epoch(model, 
              optimizer, 
              data_loader, 
              loss_func, 
              device, 
              results, 
              score_funcs, 
              prefix="", 
              desc=None):
    """
    model -- the PyTorch model / "Module" to run for one epoch
    optimizer -- the object that will update the weights of the network
    data_loader -- DataLoader object that returns tuples of (input, label) pairs. 
    loss_func -- the loss function that takes in two arguments, the model outputs and the labels, and returns a score
    device -- the compute lodation to perform training
    score_funcs -- a dictionary of scoring functions to use to evalue the performance of the model
    prefix -- a string to pre-fix to any scores placed into the _results_ dictionary. 
    desc -- a description to use for the progress bar.     
    """
    running_loss = []
    y_true = []
    y_pred = []
    start = time.time()
    for inputs, labels in tqdm(data_loader, desc=desc, leave=False):
        #Move the batch to the device we are using. 
        inputs = moveTo(inputs, device)
        labels = moveTo(labels, device)

        y_hat = model(inputs) #this just computed f_Θ(x_i)
        
        # Compute loss.
        loss = loss_func(y_hat, labels)
        if model.training:
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

        #Now we are just grabbing some information we would like to have
        running_loss.append(loss.item())

        if len(score_funcs) > 0 and isinstance(labels, torch.Tensor):
            #moving labels & predictions back to CPU for computing / storing predictions
            labels = labels.detach().cpu().numpy()
            y_hat = y_hat.detach().cpu().numpy()
            #add to predictions so far
            y_true.extend(labels.tolist())
            y_pred.extend(y_hat.tolist())
            
    #end training epoch
    end = time.time()
    
    y_pred = np.asarray(y_pred)
    
    # We have a classification problem, convert to labels
    if len(y_pred.shape) == 2 and y_pred.shape[1] > 1:
        y_pred = np.argmax(y_pred, axis=1)
    # Else, we assume we are working on a regression problem
    
    results[prefix + " loss"].append( np.mean(running_loss) )
    for name, score_func in score_funcs.items():
        try:
            results[prefix + " " + name].append( score_func(y_true, y_pred) )
        except:
            results[prefix + " " + name].append(float("NaN"))
    return end-start #time spent on epoch

# %%
def train_simple_network(model, 
                         loss_func, 
                         train_loader, 
                         test_loader=None, 
                         score_funcs=None, 
                         epochs=50, 
                         device="cpu", 
                         checkpoint_file=None, 
                         lr=0.001):
    """Train simple neural networks
    
    Keyword arguments:
    model -- the PyTorch model / "Module" to train
    loss_func -- the loss function that takes in batch in two arguments, the model outputs and the labels, and returns a score
    train_loader -- PyTorch DataLoader object that returns tuples of (input, label) pairs. 
    test_loader -- Optional PyTorch DataLoader to evaluate on after every epoch
    score_funcs -- A dictionary of scoring functions to use to evalue the performance of the model
    epochs -- the number of training epochs to perform
    device -- the compute lodation to perform training
    
    """
    to_track = ["epoch", "total time", "train loss"]
    if test_loader is not None:
        to_track.append("test loss")
    for eval_score in score_funcs:
        to_track.append("train " + eval_score )
        if test_loader is not None:
            to_track.append("test " + eval_score )
    
    # How long have we spent in the training loop? 
    total_train_time = 0 
    results = {}
    
    #Initialize every item with an empty list
    for item in to_track:
        results[item] = []
        
    pp.pprint(results)
        
    #SGD is Stochastic Gradient Decent.
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001)
    #Place the model on the correct compute resource (CPU or GPU)
    model.to(device)
    
    for epoch in tqdm(range(epochs), desc="Epoch"):
        model = model.train()#Put our model in training mode
        
        total_train_time += run_epoch(model, optimizer, train_loader, loss_func, device, results, score_funcs, prefix="train", desc="Training")

        results["total time"].append( total_train_time )
        results["epoch"].append( epoch )
        
        if test_loader is not None:
            model = model.eval()
            with torch.no_grad():
                run_epoch(model, optimizer, test_loader, loss_func, device, results, score_funcs, prefix="test", desc="Testing")
                    
    if checkpoint_file is not None:
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'results' : results
            }, checkpoint_file)

    return pd.DataFrame.from_dict(results)

# %% [markdown]
# With this we have improved our code. Now, let's re-train the model on the moon dataset.

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
# Generate train and test data
X_train, y_train = make_moons(n_samples=8000, noise=0.4)
X_test, y_test = make_moons(n_samples=200, noise=0.4)

train_dataset = torch.utils.data.TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train,
dtype=torch.long))

test_dataset = torch.utils.data.TensorDataset(torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test,
dtype=torch.long))

training_loader = DataLoader(train_dataset, shuffle=True)
testing_loader = DataLoader(test_dataset)

# %%
# Create our model
model = nn.Sequential(
    nn.Linear(2, 30),
    nn.Tanh(),
    nn.Linear(30, 30),
    nn.Tanh(),
    nn.Linear(30,2),
)

# %%
# Train our model
results_pd = train_simple_network(model,
                                  loss_func,
                                  training_loader,
                                  epochs=5,
                                  test_loader=testing_loader,
                                  checkpoint_file='model.pt',
                                  score_funcs={
                                      'Acc':accuracy_score,
                                      'F1': f1_score})
# Out:
# {   'epoch': [],
#     'test Acc': [],
#     'test F1': [],
#     'test loss': [],
#     'total time': [],
#     'train Acc': [],
#     'train F1': [],
#     'train loss': []}
# ...
# Testing:   0%|          | 0/200 [00:00<?, ?it/s]

# %% [markdown]
# Now lets see that we can load and our check point model. in order to load a model, we need to define a new model that has all the same sub-modules as the original, and they all need to be the same size.
#
# This is necessary so that the weights all match up. if you saved a model with 30 neurons in the second hidden layer, we need to have the same size as well, or else it will raise an error.
#
# We use the <code> torch.load </code> and <code> torch.save </code> for its <code> map_location </code> argument. This will handle model load to the correct compute device for us. Once we load in the dictionary of results, we can use the <code> load_state_dict </code> function to restore the state of our original model into this new object.

# %%
# Before loading
model_new = nn.Sequential(
    nn.Linear(2, 30),
    nn.Tanh(),
    nn.Linear(30, 30),
    nn.Tanh(),
    nn.Linear(30,2),
)

visualize2DSoftmax(X_test, y_test, model_new, title="Initial Model")
# Out:
# <ipython-input-19-319312e34d6c>:19: MatplotlibDeprecationWarning:
# The ax attribute was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   sns.scatterplot(x=X[:,0], y=X[:,1], hue=y, style=y, ax=cs.ax)
# <ipython-input-19-319312e34d6c>:22: MatplotlibDeprecationWarning:
# The ax attribute was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   cs.ax.set_title(title)

# %%
# After loading
checkpoint_dict = torch.load('model.pt', map_location=device)
model_new.load_state_dict(checkpoint_dict['model_state_dict'])
visualize2DSoftmax(X_test, y_test, model_new, title="Loaded Model")
# Out:
# <ipython-input-19-319312e34d6c>:19: MatplotlibDeprecationWarning:
# The ax attribute was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   sns.scatterplot(x=X[:,0], y=X[:,1], hue=y, style=y, ax=cs.ax)
# <ipython-input-19-319312e34d6c>:22: MatplotlibDeprecationWarning:
# The ax attribute was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   cs.ax.set_title(title)

# %% [markdown]
# model_new = nn.Sequential (

# %% [markdown]
# Our new training function return a panda dataframe object with information of the model after every epoch. this gives us some valuable information.
#
# Below is the plot of the training and validation accuracy as a function of the epoch finished.

# %%
sns.lineplot(x='epoch', y='train Acc', data=results_pd, label='Train')
sns.lineplot(x='epoch', y='test Acc', data=results_pd, label='Validation')
plt.show()

# %% [markdown]
# If we want to compare how quickly two different models can learn.

# %%
sns.lineplot(x='total time', y='train F1', data=results_pd, label='Train')
sns.lineplot(x='total time', y='test F1', data=results_pd, label='Validation')
plt.show()

# %% [markdown]
# ## Training in Batches

# %% [markdown]
# Training the model over the whole data takes time. We can fix this through training with batch of data.
#
# Suppose that we have the following dataset of $N=4$ items.
#
# $$
# X^{4\times 2} =
# \left[\begin{array}{cc}
# x_1=[1,2]\\
# x_1=[3,4]\\
# x_1=[5,6]\\
# x_1=[7,8]
# \end{array}\right]
# , y =
# \left[\begin{array}{cc}
# 0\\
# 1\\
# 1\\
# 0
# \end{array}\right]
# $$
#
# Our current code, over one epoch, will perform four updates, one for each item in the dataset. This is called stochastic in jargon we use to mean "random".
#
# The stochastic part of the name SGD comes from us using only a portion of the
# shuffled data, instead of the whole dataset, to compute the gradient. Because it is shuffled we will get a different result every time.

# %% [markdown]
# If we push all $N$ data points through the model and compute the loss over the whole datasets, $\nabla \sum_{i=1}^N l(f(x_i),y_i)$, we will get the true gradient. This can also make our training more computationally efficient by processing all of the data at once instead of one at a time.
#
# So, instead of passing a vector with the shape of $d$ input feature, we pass matrix with a shape of $(N, d)$.
#
# If unspecified, it defaults to <code>batch_size=1</code>. If we set this to <code>batch_size=len(train_dataset)</code>, then we will perform true gradient descent.

# %%
training_loader = DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=True)
testing_loader = DataLoader(test_dataset, batch_size=len(test_dataset))

model_gd = nn.Sequential(
    nn.Linear(2, 30),
    nn.Tanh(),
    nn.Linear(30, 30),
    nn.Tanh(),
    nn.Linear(30,2),
)

results_true_gd = train_simple_network(model_gd, loss_func, training_loader, epochs=5,
test_loader=testing_loader, checkpoint_file='model_gd.pt',
score_funcs={'Acc':accuracy_score,'F1': f1_score})
# Out:
# {   'epoch': [],
#     'test Acc': [],
#     'test F1': [],
#     'test loss': [],
#     'total time': [],
#     'train Acc': [],
#     'train F1': [],
#     'train loss': []}
# ...
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sns.lineplot(x='total time', y='test Acc', data=results_pd, label='SGD, B=1')
sns.lineplot(x='total time', y='test Acc', data=results_true_gd, label='GD, B=N')
plt.show()

# %% [markdown]
# Read Inside Deap Learning: Math, Algorithms, Models MEAP page 64 for more explanation on SGD vs GD with true gradient calculation.
#
# Summary:
#
# GD with batch of $N$ shows that the results heading to the correct direction. However, each step is expensive.
#
# On the other hand, SGD which takes batch number of $B=1$ , we preform $N$ updates per epoch so we get more steps in a fixed number of epoch. But, because of the stochastic or “random”
# behavior of using just one data point for each update, the steps we take are noisy.
#
# The best way is to find the balance between both.

# %%
training_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)
model_sgd = nn.Sequential(
    nn.Linear(2, 30),
    nn.Tanh(),
    nn.Linear(30, 30),
    nn.Tanh(),
    nn.Linear(30,2)
)

results_batched = train_simple_network(model_sgd, loss_func, training_loader, epochs=5,
test_loader=testing_loader, checkpoint_file='modelSGDxGD.pt',
score_funcs={'Acc':accuracy_score,'F1': f1_score})
# Out:
# {   'epoch': [],
#     'test Acc': [],
#     'test F1': [],
#     'test loss': [],
#     'total time': [],
#     'train Acc': [],
#     'train F1': [],
#     'train loss': []}
# ...
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sns.lineplot(x='total time', y='test Acc', data=results_pd, label='SGD, B=1')
sns.lineplot(x='total time', y='test Acc', data=results_true_gd, label='GD, B=N')
sns.lineplot(x='total time', y='test Acc', data=results_batched, label='SGD, B=32')
plt.show()
